# %%
# %run KMeanModule.ipynb

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('K_means_data.xlsx')
X=np.array(data)

# %%
test=KMean(X,no_K=4)

# %%
test.Run()

# %%
test.Get_Parameters()
# Out:
# no_K: 4
# iterations: 5
# plot: True

# %%
test.Get_Kmeans()
# Out:
# [[ 5.38423044  5.17133492]
#  [-5.72882791 -0.70942653]
#  [ 3.33835619 -4.80522897]
#  [-3.67964977  4.5454365 ]]

# %%
test.Get_Output()
# Out:
# array([[-4.68710272,  6.45669487,  3.        ],
#        [-8.12999156,  4.1410344 ,  1.        ],
#        [-5.43439621,  3.881037  ,  1.        ],
#        [-7.33296878,  6.95949262,  1.        ],
#        [-4.93458734,  7.22975143,  3.        ],
#        [-7.4896718 ,  3.02003088,  1.        ],
#        [-1.87484413,  5.51603382,  3.        ],
#        [-4.97059844,  3.05046378,  1.        ],
#        [-5.99853601,  5.75636707,  1.        ],
#        [-4.51182837,  5.73916542,  3.        ],
#        [-3.14754034, -3.68625131,  1.        ],
#        [-5.58857773, -4.8599815 ,  1.        ],
#        [-4.1796733 , -3.76076744,  1.        ],
#        [-2.83257838, -8.19647793,  2.        ],
#        [-5.45574962, -5.25754811,  1.        ],
#        [-7.33644027, -5.56701191,  1.        ],
#        [-4.91977669, -6.21665074,  1.        ],
#        [-6.70173405, -4.42660888,  1.        ],
#        [-2.38988628, -2.21446306,  3.        ],
#        [-3.51793591, -2.96557724,  1.        ],
# ...
